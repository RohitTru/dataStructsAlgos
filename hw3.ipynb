# %%
"""
Queue class used for Problem 1
"""
class Queue:
    def __init__(self):
        self.items = [] #Initializes an empty queue.

    def isEmpty(self):
        return self.items == [] #Returns True if the queue is empty; otherwise, False.

    def enqueue(self, item):
        self.items.insert(0, item) #Adds an item to the end of the queue.

    def dequeue(self):
        return self.items.pop() #Removes and returns the item from the front of the queue.

    def size(self):
        return len(self.items) #Returns the number of items in the queue.

"""
Node class used for Problem 2-5
"""
class Node:
    def __init__(self, data): #Initializes a node with the given data.
        self.data = data
        self.next = None

    def getData(self): #Returns the data stored in the node.
        return self.data

    def getNext(self): #Returns the reference to the next node.
        return self.next

    def setData(self, data): #Sets the data of the node.
        self.data = data

    def setNext(self, node): #Sets the reference to the next node.
        self.next = node



"""
1. Stack2 class
Implement stack data structure using queue
"""
class Stack2:
    def __init__(self): #The initialization method for the stack.
        # Write your definition for __init__ here
        return

    def isEmpty(self): #Returns True if the stack is empty; otherwise, False.
        # Write your definition for isEmpty here
        return

    def push(self, item): #Adds an item to the stack.
        # Write your definition for push here
        return

    def pop(self):
        # Write your definition for pop here
        return

    def peek(self):
        # Write your definition for peek here
        return

    def size(self):
        # Write your definition for size here
        return


"""
2. transform(lst)
Transform an unordered list into a Python list
Input: an (possibly empty) unordered list
Output: a Python list
"""
def transform(lst):
    # Write your code here
        return



"""
3. concatenate(lst1, lst2)
Concatenate two unordered lists
Input: two (possibly empty) unordered list
Output: an unordered list
"""
def concatenate(lst1, lst2):
    # Write your code here
    return



"""
4. removeNodesFromBeginning(lst, n)
Remove the first n nodes from an unordered list
Input:
    lst -- an (possibly empty) unordered list
... (45 lines left)
